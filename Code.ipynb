# %%
import geopandas as gpd
from srai.loaders import OSMOnlineLoader
from srai.regionalizers import H3Regionalizer
from srai.joiners import IntersectionJoiner
from srai.utils import geocode_to_region_gdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import geopandas as gpd
# ----> 2 from srai.loaders import OSMOnlineLoader
#       3 from srai.regionalizers import H3Regionalizer
#       4 from srai.joiners import IntersectionJoiner
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/srai/loaders/__init__.py:12
#      10 from .geoparquet_loader import GeoparquetLoader
#      11 from .gtfs_loader import GTFSLoader
# ---> 12 from .osm_loaders import OSMLoader, OSMOnlineLoader, OSMPbfLoader, OSMTileLoader
#      13 from .osm_way_loader import OSMWayLoader
#      15 __all__ = [
#      16     "Loader",
#      17     "GeoparquetLoader",
#    (...)
#      23     "OSMTileLoader",
#      24 ]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/srai/loaders/osm_loaders/__init__.py:6
#       4 from .osm_online_loader import OSMOnlineLoader
#       5 from .osm_pbf_loader import OSMPbfLoader
# ----> 6 from .osm_tile_loader import OSMTileLoader
#       8 __all__ = ["OSMLoader", "OSMOnlineLoader", "OSMPbfLoader", "OSMTileLoader"]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/srai/loaders/osm_loaders/osm_tile_loader.py:15
#      12 import pandas as pd
#      13 import requests
# ---> 15 from srai.regionizers.slippy_map_regionizer import SlippyMapRegionizer
#      16 from srai.utils._optional import import_optional_dependencies
#      18 from .osm_tile_data_collector import (
#      19     DataCollector,
#      20     DataCollectorType,
#      21     InMemoryDataCollector,
#      22     get_collector,
#      23 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/srai/regionizers/__init__.py:12
#      10 from ._base import Regionizer
#      11 from .administrative_boundary_regionizer import AdministrativeBoundaryRegionizer
# ---> 12 from .h3_regionizer import H3Regionizer
#      13 from .s2_regionizer import S2Regionizer
#      14 from .slippy_map_regionizer import SlippyMapRegionizer
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/srai/regionizers/h3_regionizer.py:27
#      23 from srai.regionizers import Regionizer
#      24 from srai.utils import buffer_geometry
# ---> 27 class H3Regionizer(Regionizer):
#      28     """
#      29     H3 Regionizer.
#      30
#      31     H3 Regionizer allows the given geometries to be divided
#      32     into H3 cells - hexagons with pentagons as a very rare exception
#      33     """
#      35     def __init__(self, resolution: int, buffer: bool = True) -> None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/srai/regionizers/h3_regionizer.py:100, in H3Regionizer()
#      96     gdf_h3_clipped.index.name = REGIONS_INDEX
#      98     return gdf_h3_clipped.to_crs(gdf.crs)
# --> 100 def _polygon_shapely_to_h3(self, polygon: geometry.Polygon) -> h3.Polygon:
#     101     """
#     102     Convert Shapely Polygon to H3 Polygon.
#     103
#    (...)
#     108         h3.Polygon: Converted polygon.
#     109     """
#     110     exterior = [coord[::-1] for coord in list(polygon.exterior.coords)]
#
# AttributeError: module 'h3' has no attribute 'Polygon'
